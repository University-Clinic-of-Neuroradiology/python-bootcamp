# %% [markdown]
# # Introduction to Time Analysis in python
#
# You'll learn how to load and analyze medical time series, such as EEG, ECG and EMG.
#
# This demo is a jupyter notebook, i.e. intended to be run step by step.
#
# Author: Eric Einspänner
# <br>
# Contributor: Nastaran Takmilhomayouni
#
# First version: 6th of July 2023 # to be changed
#
#
# Copyright 2023 Clinic of Neuroradiology, Magdeburg, Germany
#
# License: Apache-2.0

# %% [markdown]
# https://medium.com/@lalesena/how-to-analyze-ecgs-with-python-396e34ece937

# %% [markdown]
# https://github.com/MIT-LCP/wfdb-python/tree/main/sample-data

# %% [markdown]
# ## Table Of Contents
# 0. [Initial Set-Up (offline)](#Initial-Set-Up-(offline))
# 1. [File Formats](#Medical-signals-file-formats)

# %% [markdown]
# ## Initial Set-Up (offline)

# %%
#To work with EEG files, you need to import the following libraries in python

# mne: open-source Python package for exploring, visualizing, and analyzing human
# neurophysiological data: MEG, EEG, sEEG, ECoG, NIRS, and more.
import mne 

#To work with ECG and EMG files, you need to import the followig libraries in python
#To work with EMG files only as text file, you can open it with python open function

#wfdb: The native Python waveform-database (WFDB) package. A library of tools for
#reading, writing, and processing WFDB signals and annotations.
import wfdb

#To apply time and frequency anylsis on EMG signals, you can benefit useful functionalities from biosignalsnotebooks python package
#biosignalsnotebooks: https://github.com/pluxbiosignals/biosignalsnotebooks
import biosignalsnotebooks as bsnb

# %% [markdown]
# ## Medical signals file formats
#
# | Signal Type | File Extension       | Origin                                         |
# |-------------|----------------------|------------------------------------------------|
# | EEG         | .fif                 | Fractal Image Format                           |
# |             | .edf                 | European data Format                           |
# |             | .eeg                 | BrainVision                                    |
# |             | .vhdr                | BrainVision                                    |
# |             | .vmrk                | BrainVision                                    |
# |             | .bdf                 | BioSemi data Format                            |
# |             | .gdf                 | General data Format                            |
# |             | .cnt                 | Neuroscan CNT                                  |
# |             | .egi                 | EGI simple binary                              |
# |             | .mff                 | EGI MFF                                        |
# |             | .set,.fdt            | EEGLAB files                                   |
# |             | .data                | Nicolet                                        |
# |             | .nxe                 | eXimia EEG data                                |
# |             | .lay .dat            | Persyst EEG data                               |
# |             | .eeg,.21e,.pnt,.log  | Nihon Kohden EEG data                          |
# |             | .xdf,.xdfz)          | XDF data                                       |
# | ECG         | .qrs                 | Fractal Image Format                           |
# |             | .xws                 | European data Format                           |
# |             | .dat/.hea            | Header( Analyze Software, Mayo Clinic )        |
# | EMG         | .txt                 | Text                                           |
# |             | .mat/.hea            | Header( Analyze Software, Mayo Clinic          |
