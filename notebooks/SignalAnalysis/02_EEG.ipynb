# %% [markdown]
# ## fif

# %%
import mne
sample_data_folder = mne.datasets.sample.data_path()
sample_data_raw_file = (
    sample_data_folder / "MEG" / "sample" / "sample_audvis_filt-0-40_raw.fif"
)
raw = mne.io.read_raw_fif(sample_data_raw_file)
# Out:
# Opening raw data file C:\Users\nasta\mne_data\MNE-sample-data\MEG\sample\sample_audvis_filt-0-40_raw.fif...
#     Read a total of 4 projection items:
#         PCA-v1 (1 x 102)  idle
#         PCA-v2 (1 x 102)  idle
#         PCA-v3 (1 x 102)  idle
#         Average EEG reference (1 x 60)  idle
#     Range : 6450 ... 48149 =     42.956 ...   320.665 secs
# Ready.

# %% [markdown]
# ## edf

# %%
subj=0
fname = mne.datasets.eegbci.load_data(subj + 1, runs=[3])[0]
print(fname)
raw = mne.io.read_raw_edf(fname).load_data().resample(50)
# Out:
# Using default location ~/mne_data for EEGBCI...
# Downloading EEGBCI data
# Downloading file 'S001/S001R03.edf' from 'https://physionet.org/files/eegmmidb/1.0.0/S001/S001R03.edf' to 'C:\Users\nasta\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0'.
# Do you want to set the path:
#     C:\Users\nasta\mne_data
# as the default EEGBCI dataset path in the mne-python config [y]/n? y
# Download complete in 10s (2.5 MB)
# C:\Users\nasta\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S001\S001R03.edf
# Extracting EDF parameters from C:\Users\nasta\mne_data\MNE-eegbci-data\files\eegmmidb\1.0.0\S001\S001R03.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 19999  =      0.000 ...   124.994 secs...

# %% [markdown]
# ## bdf

# %%
sample_bdf_file='Data/EEG/Newtest17-2048.bdf'
raw = mne.io.read_raw_bdf(sample_bdf_file)
# Out:
# Extracting EDF parameters from C:\Users\nasta\OneDrive\Dokumente\GitHub\python-bootcamp\notebooks\SignalAnalysis\Data\EEG\Newtest17-2048.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %% [markdown]
# ## gdf

# %%
sample_gdf_file='Data/EEG/A08T.gdf'
raw=mne.io.read_raw_gdf(sample_gdf_file)
# Out:
# Extracting EDF parameters from C:\Users\nasta\OneDrive\Dokumente\GitHub\python-bootcamp\notebooks\SignalAnalysis\Data\EEG\A08T.gdf...
# GDF file detected
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG, EOG-left, EOG-central, EOG-right
# Creating raw.info structure...
# C:\Users\nasta\anaconda3\lib\contextlib.py:126: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)

# %% [markdown]
# ## eeglab

# %%
testing_data_folder = mne.datasets.testing.data_path()
eeglab_raw_file = testing_data_folder / "EEGLAB" / "test_raw.set"
eeglab_raw = mne.io.read_raw_eeglab(eeglab_raw_file)
print(eeglab_raw.annotations)
# Out:
# Using default location ~/mne_data for testing...
# Dataset testing version 0.0 out of date, latest version is 0.147
# Downloading file 'mne-testing-data-0.147.tar.gz' from 'https://codeload.github.com/mne-tools/mne-testing-data/tar.gz/0.147' to 'C:\Users\nasta\mne_data'.
# 0.00B [00:00, ?B/s]
# Untarring contents of 'C:\Users\nasta\mne_data\mne-testing-data-0.147.tar.gz' to 'C:\Users\nasta\mne_data'
# Download complete in 06m12s (1025.0 MB)
# Reading C:\Users\nasta\mne_data\MNE-testing-data\EEGLAB\test_raw.fdt
# <Annotations | 154 segments: rt (74), square (80)>

# %%
raw.plot(start=5, duration=5)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1108.08x607.68 with 4 Axes>
# <MNEBrowseFigure size 1108.08x607.68 with 4 Axes>
