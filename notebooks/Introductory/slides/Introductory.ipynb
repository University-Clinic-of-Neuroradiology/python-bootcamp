# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %% [markdown]
# ![Picture2.png](attachment:Picture2.png)

# %% [markdown]
# ![Picture3.png](attachment:Picture3.png)

# %% [markdown]
# ## Basic data types

# %% [markdown]
# ### Integer

# %%
x = 5
print(x)
print(type(x))
# Out:
# 5
# <class 'int'>

# %% [markdown]
# ### Float

# %%
x = 2.53
print(x)
print(type(x))
# Out:
# 2.53
# <class 'float'>

# %% [markdown]
# ### Booleans

# %%
t, f = True, False
print(type(t))
# Out:
# <class 'bool'>

# %% [markdown]
# ### Strings

# %%
hello = 'hello' 
print(type(hello))
# Out:
# <class 'str'>

# %% [markdown]
# ## Containers

# %% [markdown]
# ### Lists

# %%
otherlist = [1, 2, True, 3.14, "students"]
print(type(otherlist))
# Out:
# <class 'list'>

# %% [markdown]
# #### Slicing

# %%
nums = [*range(5)]     # range is a built-in function to initialize a sequence of numbers
print(nums[2:4])
# Out:
# [2, 3]

# %% [markdown]
# #### List comprehensions

# %%
squares = [x ** 2 for x in nums]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# #### Loop lists

# %%
animals = ['cat', 'dog', 'monkey']
for idx, animal in enumerate(animals):
    print('#%d: %s' % (idx, animal))
# Out:
# #0: cat
# #1: dog
# #2: monkey

# %% [markdown]
# ### Dictionaries

# %%
d = {'ostrich': 2, 'dog': 4, 'spider': 8}
d
# Out:
# {'ostrich': 2, 'dog': 4, 'spider': 8}

# %% [markdown]
# ## Basic Operations with Python

# %% [markdown]
# ### Basic Arithmetic Operations

# %%
a = 12
b = 2

print(a + b,a**b,a/b)
# Out:
# 14 144 6.0

# %% [markdown]
# ## Loops

# %% [markdown]
# ### While Loops

# %%
fib = [1, 1, 2, 3, 5, 8]

#While loops are the basic type
i = 0
while(i < len(fib)):
    print(fib[i])
    i = i + 1
# Out:
# 1
# 1
# 2
# 3
# 5
# 8

# %% [markdown]
# ### For Loops

# %%
for num in fib:
    print(num)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8

# %% [markdown]
# ## Conditionals and Libraries

# %% [markdown]
# ### if-else Statement

# %%
answer = 3.14

if answer == 3.14:
    print('Yeah! That\'s correct!')
else:
    print('Pity. Try again.')
# Out:
# Yeah! That's correct!

# %% [markdown]
# ### if-elif-else Statement

# %%
answer = 42

if answer == 42:
    print('This is the answer to the ultimate question')
elif answer < 42:
    print('This is less than the answer to the ultimate question')
# Out:
# This is the answer to the ultimate question

# %% [markdown]
# ## Functions

# %%
def step(x):
    if (x < 0):
        return -1
    elif (x > 0):
        return 1
    
print(step(10))
# Out:
# 1

# %% [markdown]
# ## Libraries

# %% [markdown]
# ### Numpy

# %%
import numpy as np

# %% [markdown]
# #### Mathematical constants

# %%
print(np.pi)
print(np.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %% [markdown]
# #### trignometric functions

# %%
print(np.sin(np.pi/4))
print(np.cos(np.pi/4))
print(np.tan(np.pi/4))
# Out:
# 0.7071067811865476
# 0.7071067811865476
# 0.9999999999999999

# %% [markdown]
# #### numpy array

# %%
list=[1,2,3,4]
numpy_array=np.array(list)
print(numpy_array)
# Out:
# [1 2 3 4]

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### plotting functionality

# %%
x = np.linspace(0,10)
y = np.sin(x)

# plot
plt.plot(x, y)

# %% [markdown]
# ### Pandas

# %%
import pandas as pd

# %% [markdown]
# #### Dataframe

# %%
mydict = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

# Pandas can convert python dictionary to an structure called DataFrame
mydtframe = pd.DataFrame(mydict)
mydtframe
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# #### Series

# %%
mylist = [1, 7, 2]

# Pandas can convert python list to an structure called Series
myseries = pd.Series(mylist)
myseries
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# #### CSV

# %%
csv2df = pd.read_csv('Data/data.csv')
csv2df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# #### JSON

# %%
jsn2df = pd.read_json('Data/data.json') 
jsn2df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ## Python Error Handling

# %% [markdown]
# ### Tracebacks

# %%
#text pointing to the origin (and ending) of an unhandled error.
open("/file/doesnt/exists.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9720/2765524044.py in <module>
#       1 #text pointing to the origin (and ending) of an unhandled error.
# ----> 2 open("/file/doesnt/exists.jpg")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/file/doesnt/exists.jpg'

# %% [markdown]
# ### Try and Except blocks

# %%
try:
     open('config.txt')
except FileNotFoundError:
     print("Couldn't find the config.txt file!")
# Out:
# Couldn't find the config.txt file!

# %% [markdown]
# ### Raise exceptions

# %%
#Use raise to alert for the error condition!!
#RuntimeError: will stop the program to continue

def medication_left(patients, tablets_left, days_left):
    daily_usage = patients * 3
    total_usage = daily_usage * days_left
    total_tablets_left = tablets_left - total_usage
    if total_tablets_left < 0:
        raise RuntimeError(f"There is not enough tablets for {patients} patients after {days_left} days!")
    return f"Total tablets left after {days_left} days is: {total_tablets_left}!"

medication_left(3, 15, 2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9720/3419558201.py in <module>
#       9     return f"Total tablets left after {days_left} days is: {total_tablets_left}!"
#      10
# ---> 11 medication_left(3, 15, 2)
#
# ~\AppData\Local\Temp/ipykernel_9720/3419558201.py in medication_left(patients, tablets_left, days_left)
#       6     total_tablets_left = tablets_left - total_usage
#       7     if total_tablets_left < 0:
# ----> 8         raise RuntimeError(f"There is not enough tablets for {patients} patients after {days_left} days!")
#       9     return f"Total tablets left after {days_left} days is: {total_tablets_left}!"
#      10
#
# RuntimeError: There is not enough tablets for 3 patients after 2 days!
