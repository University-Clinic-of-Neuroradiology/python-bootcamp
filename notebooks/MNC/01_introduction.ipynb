# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt
img = nib.load('subject04.mnc')
data = img.get_fdata()
print(data.mean())
print(data.max())
print(data.min())
print(type(data))
print(np.shape(data))
# Out:
# 2.4194904212705426
# 11.0
# 0.0
# <class 'numpy.ndarray'>
# (362, 434, 362)

# %%
plt.figure()
plt.imshow(data[:,100,:],cmap='gray')
